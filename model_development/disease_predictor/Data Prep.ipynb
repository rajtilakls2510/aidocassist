# %% [markdown]
# ## Notebook AIM: Prepare the raw dataset for model training

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
DISEASE_PRED_PATH = "/content/drive/MyDrive/AIDocAssist/Disease_predictor"

# %%
import numpy as np
import pandas as pd

# %%
severity = pd.read_csv(DISEASE_PRED_PATH+"/Symptom-severity.csv")
dataset = pd.read_csv(DISEASE_PRED_PATH+"/dataset.csv")
desc = pd.read_csv(DISEASE_PRED_PATH+"/symptom_Description.csv")
precaution = pd.read_csv(DISEASE_PRED_PATH+"/symptom_precaution.csv")

# %% [markdown]
# # Severity

# %%
severity.head()
# Out:
#                 Symptom  weight
# 0               itching       1
# 1             skin_rash       3
# 2  nodal_skin_eruptions       4
# 3   continuous_sneezing       4
# 4             shivering       5

# %%
severity.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 133 entries, 0 to 132
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Symptom  133 non-null    object
#  1   weight   133 non-null    int64
# dtypes: int64(1), object(1)
# memory usage: 2.2+ KB

# %%
severity.weight.unique()
# Out:
# array([1, 3, 4, 5, 6, 2, 7])

# %%
severity.drop_duplicates(subset="Symptom", keep='first', inplace=True)

# %%
severity.replace(1,2, inplace=True)

# %%
severity["Type"]=np.where(severity["weight"]==2, "mild", 
                          np.where(severity["weight"]==3, "mild", 
                                   np.where(severity["weight"]==4, "moderate", 
                                            np.where(severity["weight"]==5, "moderate", 
                                                     np.where(severity["weight"]==6, "severe", 
                                                              np.where(severity["weight"]==7, "severe", np.nan))))))

# %%
severity[severity["Type"]=="moderate"]
# Out:
#                             Symptom  weight      Type
# 2              nodal_skin_eruptions       4  moderate
# 3               continuous_sneezing       4  moderate
# 4                         shivering       5  moderate
# 7                      stomach_pain       5  moderate
# 9                  ulcers_on_tongue       4  moderate
# ..                              ...     ...       ...
# 116  history_of_alcohol_consumption       5  moderate
# 118                 blood_in_sputum       5  moderate
# 120                    palpitations       4  moderate
# 129                         blister       4  moderate
# 132                       prognosis       5  moderate
#
# [73 rows x 3 columns]

# %%
severity.drop(index=132, inplace=True)

# %%
severity.to_csv(DISEASE_PRED_PATH+"/New_symptom_severity.csv", index=False)

# %% [markdown]
# # Description

# %%
desc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41 entries, 0 to 40
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Disease      41 non-null     object
#  1   Description  41 non-null     object
# dtypes: object(2)
# memory usage: 784.0+ bytes

# %%
desc['Disease'].unique()
# Out:
# array(['Drug Reaction', 'Malaria', 'Allergy', 'Hypothyroidism',
#        'Psoriasis', 'GERD', 'Chronic cholestasis', 'hepatitis A',
#        'Osteoarthristis', '(vertigo) Paroymsal  Positional Vertigo',
#        'Hypoglycemia', 'Acne', 'Diabetes', 'Impetigo', 'Hypertension',
#        'Peptic ulcer diseae', 'Dimorphic hemorrhoids(piles)',
#        'Common Cold', 'Chicken pox', 'Cervical spondylosis',
#        'Hyperthyroidism', 'Urinary tract infection', 'Varicose veins',
#        'AIDS', 'Paralysis (brain hemorrhage)', 'Typhoid', 'Hepatitis B',
#        'Fungal infection', 'Hepatitis C', 'Migraine', 'Bronchial Asthma',
#        'Alcoholic hepatitis', 'Jaundice', 'Hepatitis E', 'Dengue',
#        'Hepatitis D', 'Heart attack', 'Pneumonia', 'Arthritis',
#        'Gastroenteritis', 'Tuberculosis'], dtype=object)

# %% [markdown]
# # Precautions

# %%
precaution.head()
# Out:
#           Disease  ...                 Precaution_4
# 0   Drug Reaction  ...                    follow up
# 1         Malaria  ...           keep mosquitos out
# 2         Allergy  ...  use ice to compress itching
# 3  Hypothyroidism  ...             get proper sleep
# 4       Psoriasis  ...                   salt baths
#
# [5 rows x 5 columns]

# %%
precaution.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41 entries, 0 to 40
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Disease       41 non-null     object
#  1   Precaution_1  41 non-null     object
#  2   Precaution_2  41 non-null     object
#  3   Precaution_3  40 non-null     object
#  4   Precaution_4  40 non-null     object
# dtypes: object(5)
# memory usage: 1.7+ KB

# %%
precaution["Disease"] = precaution["Disease"].str.strip()

# %%
disease_merged=desc.merge(precaution, on="Disease",how="left")

# %%
disease_merged.to_csv(DISEASE_PRED_PATH+"/Disease_desc_prec.csv", index=False)

# %% [markdown]
# # Dataset

# %%
dataset.head()
# Out:
#             Disease   Symptom_1  ... Symptom_16 Symptom_17
# 0  Fungal infection     itching  ...        NaN        NaN
# 1  Fungal infection   skin_rash  ...        NaN        NaN
# 2  Fungal infection     itching  ...        NaN        NaN
# 3  Fungal infection     itching  ...        NaN        NaN
# 4  Fungal infection     itching  ...        NaN        NaN
#
# [5 rows x 18 columns]

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4920 entries, 0 to 4919
# Data columns (total 18 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Disease     4920 non-null   object
#  1   Symptom_1   4920 non-null   object
#  2   Symptom_2   4920 non-null   object
#  3   Symptom_3   4920 non-null   object
#  4   Symptom_4   4572 non-null   object
#  5   Symptom_5   3714 non-null   object
#  6   Symptom_6   2934 non-null   object
#  7   Symptom_7   2268 non-null   object
#  8   Symptom_8   1944 non-null   object
#  9   Symptom_9   1692 non-null   object
#  10  Symptom_10  1512 non-null   object
#  11  Symptom_11  1194 non-null   object
#  12  Symptom_12  744 non-null    object
#  13  Symptom_13  504 non-null    object
#  14  Symptom_14  306 non-null    object
#  15  Symptom_15  240 non-null    object
#  16  Symptom_16  192 non-null    object
#  17  Symptom_17  72 non-null     object
# dtypes: object(18)
# memory usage: 692.0+ KB

# %%
dataset.isna().sum()
# Out:
# Disease          0
# Symptom_1        0
# Symptom_2        0
# Symptom_3        0
# Symptom_4      348
# Symptom_5     1206
# Symptom_6     1986
# Symptom_7     2652
# Symptom_8     2976
# Symptom_9     3228
# Symptom_10    3408
# Symptom_11    3726
# Symptom_12    4176
# Symptom_13    4416
# Symptom_14    4614
# Symptom_15    4680
# Symptom_16    4728
# Symptom_17    4848
# dtype: int64

# %%
dataset.iloc[:,1:]=dataset.iloc[:,1:].replace(" ","", regex=True)

# %%
dataset.head()
# Out:
#             Disease  Symptom_1  ... Symptom_16 Symptom_17
# 0  Fungal infection    itching  ...        NaN        NaN
# 1  Fungal infection  skin_rash  ...        NaN        NaN
# 2  Fungal infection    itching  ...        NaN        NaN
# 3  Fungal infection    itching  ...        NaN        NaN
# 4  Fungal infection    itching  ...        NaN        NaN
#
# [5 rows x 18 columns]

# %%
diseases = dataset["Disease"].values

# %%
symptoms_diseases = dataset.iloc[:,1:].apply(lambda row: row.to_list(), axis=1).values

# %%
training_dataset = pd.DataFrame(columns=severity['Symptom'].values, index=dataset.index)
training_dataset.replace(np.nan, 0, inplace=True)
training_dataset["disease"]=diseases
training_dataset['symptoms']=symptoms_diseases
training_dataset.head()
# Out:
#    itching  ...                                           symptoms
# 0        0  ...  [itching, skin_rash, nodal_skin_eruptions, dis...
# 1        0  ...  [skin_rash, nodal_skin_eruptions, dischromic_p...
# 2        0  ...  [itching, nodal_skin_eruptions, dischromic_pat...
# 3        0  ...  [itching, skin_rash, dischromic_patches, nan, ...
# 4        0  ...  [itching, skin_rash, nodal_skin_eruptions, nan...
#
# [5 rows x 135 columns]

# %%
# Takes time to convert all columns
for i in severity['Symptom'].values:
  training_dataset[i] = training_dataset.apply(lambda x:1 if i in x.symptoms else 0, axis=1)

# %%
training_dataset.drop(columns="symptoms", inplace=True)

# %%
training_dataset.drop_duplicates(inplace=True)

# %%
training_dataset.shape
# Out:
# (4920, 134)

# %%
training_dataset.to_csv(DISEASE_PRED_PATH+"/Prepared_Data2.csv", index=False)
